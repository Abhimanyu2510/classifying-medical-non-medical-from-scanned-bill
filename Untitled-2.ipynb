# %%
import re
import pytesseract
from pdf2image import convert_from_path
import pandas as pd
import openai
import json  # Import json module for parsing the response

# %%
# Set up OpenAI API key
openai.api_key = "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"  # Replace with your actual API key

# %%
# Step 1: Extract Text from Scanned PDF using OCR
def extract_text_from_pdf(pdf_path):
    # Convert each page in PDF to an image
    images = convert_from_path(pdf_path)
    text = ""
    # Run OCR on each image page
    for image in images:
        text += pytesseract.image_to_string(image) + "\n"
    return text

# %%
def parse_individual_json_objects(content):
    # Remove markdown artifacts and whitespace
    content = re.sub(r"^```json|```$", "", content, flags=re.MULTILINE).strip()

    # Regex to match each JSON object within the list
    json_objects = re.findall(r'\{.*?\}', content, re.DOTALL)
    
    parsed_items = []
    for obj in json_objects:
        try:
            # Parse each individual JSON object and add to the list
            parsed_items.append(json.loads(obj))
        except json.JSONDecodeError as e:
            print("Failed to decode JSON object:", obj)
            continue  # Skip invalid JSON objects
    
    return parsed_items

def parse_and_classify_items_with_llm(text, chunk_size=1000):
    # Split text into manageable chunks
    text_chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
    all_items = []

    for chunk in text_chunks:
        prompt = (
            "Extract item details (name, quantity, price) and classify each item as "
            "medical or non-medical from the following bill text:\n"
            f"{chunk}\n"
            "Provide output in JSON format as an array of objects, with fields: name, quantity, price, category (medical/non-medical). "
            "Do not use additional formatting or text."
        )
        try:
            response = openai.ChatCompletion.create(
                model="gpt-4o",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant that extracts and classifies items from text."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=500,  # Adjust if necessary
                temperature=0.2
            )
            
            # Extract and parse individual JSON objects from the content
            content = response['choices'][0]['message']['content'].strip()
            items = parse_individual_json_objects(content)
            all_items.extend(items)  # Add parsed items to final list
            
        except Exception as e:
            print(f"Error parsing LLM response: {e}")
    
    return all_items

# %%
# Step 3: Structure the Data
def create_dataframe(items):
    df = pd.DataFrame(items)
    return df

# %%
pdf_path = "bill_of_items.pdf"  # Specify the actual PDF file path

# Step 1: Extract text from PDF
text = extract_text_from_pdf(pdf_path)
print("Extracted Text:", text)
# Out:
# Extracted Text: Final Bill
#
# Name: Mrs. BHUVANESHWARI V ai € y
# Age/Gender: 27 Y F & Child
# Address: NO,23, 2NDMAIN, 2ND STAGE, WOC ROAD, MAHALAKSHMIPURAM POST MR No: fren ‘¥
#
# Location: BANGALORE,KARNATAKA Visit ID;
#
# Doctor: Dr. BHARATHI RAJANNA Admission Date: seetl
#
# Department: Obstetrics & Gynaecology Ward/Bed DEL
#
# Rate Plan: Cradle Rajaji Nagar Gen_25012023 Discharge Date:
#
# Sponsor: Referred By: i} 08 | ATH] RAJANNA.
#
# Bill No: RRAJ-ICR-822(Bill Later) Bill Date:08-06-2024
#
# Charges Ord# Head Description Rate Qty Amount
#
# Packages
#
# 08-06-2024 Package Charges Lscs 106,000.00 i 106,000.00
# Sub Total: 106,000.00
#
# Diagnostics
#
# 08-06-2024 16166221 Lab Tests HCV Tri Dot 495,00 1,00 495.00
#
# 08-06-2024 16166221 Lab Tests HIV RAPID 1,731.00 1,00 1,731.00
#
# 08-06-2024 16166221 Lab Tests (VDRL) RPR QUALITATIVE- SERUM 440.00 1.00 440.00
#
# 08-06-2024 16166221 Lab Tests HBS AG SCREENING(RAPID) 1,327.00 1,00 1,327.00
# Sub Total: 3,993.00
#
# Services & Procedures
#
# 11-06-2024 Service LACTATION CONSULTATION CHARGES 1,100.00 1.00 1,100.00
#
# 11-06-2024 Service PHYSIOTHERAPY CONSULTATION 1,100.00 1.00 1,100.00
#
# 11-06-2024 Service DIET CHARGES, 1,000.00 3.00 3,000.00
#
# 11-06-2024 Service DOCUMENT PROCESSING FEE 1,000.00 1.00 1,000.00
#
# 11-06-2024 Service DIET COUNCELING CHARGE 1,100.00 1.00 1,100.00
#
# 11-06-2024 Service INFECTION PREVENTION IN IPD 200.00 3.00 600.00
#
# 11-06-2024 Service MEDICAL RECORDS 550.00. 1,00 $50.00
# Sub Total: 8,450.00
#
# Items
# 9; , SYRINGE IML - ROMSON
#
# 09-06-2024 Inventory Item (No. 2545016) 8.00 1,00 8.00
# 90183100 SYRINGE SML ROMOJET -
#
# 09-06-2024 Inventory Item ROMSON - MLP6732 21.00 2.00 42.00
# (No. 2545016)
# SYRINGE 2ML ROMOJET - ROMSON -
#
# 09-06-2024 Inventory Item MLPS903 15.00 2.00 30,00
#
# (No. 2545016)
#
# 90189099 DC ALCOHOL SWAB
#
# (No. 2545016)
#
# SYRINGE 10ML ROMOJET - ROMSON -
#
# 09-06-2024 Inventory Item MLP7742 17.00 2.00 34.00
# (No. 2545016)
# 9018 DISPOSABLE SKIN PREPARATION
#
# 09-06-2024 Inventory Item BLADE EASY GLIDE -ROMSON - MLP1980 39.00 2.00 78.00
#
# (No. 2545016)
#
# 48211010 PATIENT ID BAND PINK[ADULT]
#
# (No. 2545016)
#
# 48189000 DC UNDER PAD 60*90CM -
#
# 09-06-2024 Inventory Item MLP1782 99.00 2.00 198.00
# (No. 2545016)
# 30051090 DC HAND&SKIN SOOML
#
# 09-06-2024 Inventory Item DISINFECTANT +PUMP 410,00 1.00 410.00
# (No. 2545016)
#
# ne
# im
# S
#
# 09-06-2024 Inventory Item 2.00 440
#
# 09-06-2024 Inventory Item 15.00 1.00 15.00
#
# Address: Apollo Cradle & Children’s Hospital, 25/5, 1" Main Road, E Block Subramanya Na
#
# Apollo Spnecialtv Hosnitals Private | imi

# %%
# Step 2: Parse and classify items using LLM
items = parse_and_classify_items_with_llm(text)
print("Extracted and Classified Items:", items)
# Out:
# Extracted and Classified Items: [{'name': 'Lscs', 'quantity': 1, 'price': 106000.0, 'category': 'medical'}, {'name': 'HCV Tri Dot', 'quantity': 1, 'price': 495.0, 'category': 'medical'}, {'name': 'HIV RAPID', 'quantity': 1, 'price': 1731.0, 'category': 'medical'}, {'name': '(VDRL) RPR QUALITATIVE- SERUM', 'quantity': 1, 'price': 440.0, 'category': 'medical'}, {'name': 'HBS AG SCREENING(RAPID)', 'quantity': 1, 'price': 1327.0, 'category': 'medical'}, {'name': 'LACTATION CONSULTATION CHARGES', 'quantity': 1, 'price': 1100.0, 'category': 'medical'}, {'name': 'PHYSIOTHERAPY CONSULTATION', 'quantity': 1.0, 'price': 1100.0, 'category': 'medical'}, {'name': 'DIET CHARGES', 'quantity': 3.0, 'price': 3000.0, 'category': 'non-medical'}, {'name': 'DOCUMENT PROCESSING FEE', 'quantity': 1.0, 'price': 1000.0, 'category': 'non-medical'}, {'name': 'DIET COUNCELING CHARGE', 'quantity': 1.0, 'price': 1100.0, 'category': 'non-medical'}, {'name': 'INFECTION PREVENTION IN IPD', 'quantity': 3.0, 'price': 600.0, 'category': 'medical'}, {'name': 'MEDICAL RECORDS', 'quantity': 1.0, 'price': 50.0, 'category': 'medical'}, {'name': 'SYRINGE IML - ROMSON', 'quantity': 1.0, 'price': 8.0, 'category': 'medical'}, {'name': 'SYRINGE SML ROMOJET', 'quantity': 2.0, 'price': 42.0, 'category': 'medical'}, {'name': 'SYRINGE 2ML ROMOJET - ROMSON', 'quantity': 2.0, 'price': 30.0, 'category': 'medical'}, {'name': 'SYRINGE 10ML ROMOJET - ROMSON', 'quantity': 2.0, 'price': 34.0, 'category': 'medical'}, {'name': 'DISPOSABLE SKIN PREPARATION BLADE EASY GLIDE -ROMSON', 'quantity': 2.0, 'price': 78.0, 'category': 'medical'}, {'name': 'DC UNDER PAD 60*90CM', 'quantity': 2.0, 'price': 198.0, 'category': 'medical'}, {'name': 'DC HAND&SKIN SOOML DISINFECTANT +PUMP', 'quantity': 1.0, 'price': 410.0, 'category': 'medical'}]

# %%
# Step 3: Convert to DataFrame for structured data
df = create_dataframe(items)
print("Structured Data:", df)

# Save the output to a CSV file if needed
df.to_csv("classified_items.csv", index=False)
# Out:
# Structured Data:                                                  name  quantity     price  \
# 0                                                Lscs       1.0  106000.0
# 1                                         HCV Tri Dot       1.0     495.0
# 2                                           HIV RAPID       1.0    1731.0
# 3                       (VDRL) RPR QUALITATIVE- SERUM       1.0     440.0
# 4                             HBS AG SCREENING(RAPID)       1.0    1327.0
# 5                      LACTATION CONSULTATION CHARGES       1.0    1100.0
# 6                          PHYSIOTHERAPY CONSULTATION       1.0    1100.0
# 7                                        DIET CHARGES       3.0    3000.0
# 8                             DOCUMENT PROCESSING FEE       1.0    1000.0
# 9                              DIET COUNCELING CHARGE       1.0    1100.0
# 10                        INFECTION PREVENTION IN IPD       3.0     600.0
# 11                                    MEDICAL RECORDS       1.0      50.0
# 12                               SYRINGE IML - ROMSON       1.0       8.0
# 13                                SYRINGE SML ROMOJET       2.0      42.0
# 14                       SYRINGE 2ML ROMOJET - ROMSON       2.0      30.0
# 15                      SYRINGE 10ML ROMOJET - ROMSON       2.0      34.0
# 16  DISPOSABLE SKIN PREPARATION BLADE EASY GLIDE -...       2.0      78.0
# 17                               DC UNDER PAD 60*90CM       2.0     198.0
# 18              DC HAND&SKIN SOOML DISINFECTANT +PUMP       1.0     410.0
#
#        category
# 0       medical
# 1       medical
# 2       medical
# 3       medical
# 4       medical
# 5       medical
# 6       medical
# 7   non-medical
# 8   non-medical
# 9   non-medical
# 10      medical
# 11      medical
# 12      medical
# 13      medical
# 14      medical
# 15      medical
# 16      medical
# 17      medical
# 18      medical
